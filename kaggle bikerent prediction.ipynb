# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv('bikerent train.csv')
df1=pd.read_csv('bikerent test.csv')
df2=pd.read_csv('bikerentsample_submission.csv')

# %%
df.head()
# Out:
#    ID      dteday  season  year  Month  is_holiday  weekdaynum  is_workingday  \
# 0  A1  01-01-2011       1     0      1           0           6              0
# 1  A2  02-01-2011       1     0      1           0           0              0
# 2  A3  03-01-2011       1     0      1           0           1              1
# 3  A4  04-01-2011       1     0      1           0           2              1
# 4  A5  05-01-2011       1     0      1           0           3              1
#
#    weathersituation  atemp_normalized  humidity_normalized  \
# 0                 2          0.363625             0.805833
# 1                 2          0.353739             0.696087
# 2                 1          0.189405             0.437273
# 3                 1          0.212122             0.590435
# 4                 1          0.229270             0.436957
#
#    windspeed_normalized  total_rental
# 0              0.160446           985
# 1              0.248539           801
# ...

# %%
df1.head()
# Out:
#      ID      dteday  season  year  Month  is_holiday  weekdaynum  \
# 0  A600  22-08-2012       3     1      8           0           3
# 1  A601  23-08-2012       3     1      8           0           4
# 2  A602  24-08-2012       3     1      8           0           5
# 3  A603  25-08-2012       3     1      8           0           6
# 4  A604  26-08-2012       3     1      8           0           0
#
#    is_workingday  weathersituation  atemp_normalized  humidity_normalized  \
# 0              1                 1          0.621854             0.677083
# 1              1                 1          0.637008             0.635833
# 2              1                 2          0.647100             0.615000
# 3              0                 2          0.618696             0.712917
# 4              0                 2          0.595996             0.845833
#
#    windspeed_normalized
# 0              0.070283
# 1              0.084596
# 2              0.072146
# 3              0.244408
# ...

# %%
df.isnull().any()
# Out:
# ID                      False
# dteday                  False
# season                  False
# year                    False
# Month                   False
# is_holiday              False
# weekdaynum              False
# is_workingday           False
# weathersituation        False
# atemp_normalized        False
# humidity_normalized     False
# windspeed_normalized    False
# total_rental            False
# dtype: bool

# %%
df1.isnull().any()
# Out:
# ID                      False
# dteday                  False
# season                  False
# year                    False
# Month                   False
# is_holiday              False
# weekdaynum              False
# is_workingday           False
# weathersituation        False
# atemp_normalized        False
# humidity_normalized     False
# windspeed_normalized    False
# dtype: bool

# %%
df1
# Out:
#        ID      dteday  season  year  Month  is_holiday  weekdaynum  \
# 0    A600  22-08-2012       3     1      8           0           3
# 1    A601  23-08-2012       3     1      8           0           4
# 2    A602  24-08-2012       3     1      8           0           5
# 3    A603  25-08-2012       3     1      8           0           6
# 4    A604  26-08-2012       3     1      8           0           0
# ..    ...         ...     ...   ...    ...         ...         ...
# 126  A726  26-12-2012       1     1     12           0           3
# 127  A727  27-12-2012       1     1     12           0           4
# 128  A728  28-12-2012       1     1     12           0           5
# 129  A729  29-12-2012       1     1     12           0           6
# 130  A730  30-12-2012       1     1     12           0           0
#
#      is_workingday  weathersituation  atemp_normalized  humidity_normalized  \
# 0                1                 1          0.621854             0.677083
# ...

# %%
z=df1['ID']

# %%
df=df.drop('ID',axis=1)

# %%
df=df.drop('dteday',axis=1)

# %%
df1=df1.drop('ID',axis=1)

# %%
df1=df1.drop('dteday',axis=1)

# %%
df
# Out:
#      season  year  Month  is_holiday  weekdaynum  is_workingday  \
# 0         1     0      1           0           6              0
# 1         1     0      1           0           0              0
# 2         1     0      1           0           1              1
# 3         1     0      1           0           2              1
# 4         1     0      1           0           3              1
# ..      ...   ...    ...         ...         ...            ...
# 594       3     1      8           0           5              1
# 595       3     1      8           0           6              0
# 596       3     1      8           0           0              0
# 597       3     1      8           0           1              1
# 598       3     1      8           0           2              1
#
#      weathersituation  atemp_normalized  humidity_normalized  \
# 0                   2          0.363625             0.805833
# 1                   2          0.353739             0.696087
# ...

# %%
df1
# Out:
#      season  year  Month  is_holiday  weekdaynum  is_workingday  \
# 0         3     1      8           0           3              1
# 1         3     1      8           0           4              1
# 2         3     1      8           0           5              1
# 3         3     1      8           0           6              0
# 4         3     1      8           0           0              0
# ..      ...   ...    ...         ...         ...            ...
# 126       1     1     12           0           3              1
# 127       1     1     12           0           4              1
# 128       1     1     12           0           5              1
# 129       1     1     12           0           6              0
# 130       1     1     12           0           0              0
#
#      weathersituation  atemp_normalized  humidity_normalized  \
# 0                   1          0.621854             0.677083
# 1                   1          0.637008             0.635833
# ...

# %%
X=df.drop(['total_rental'], axis = 1)
y=df['total_rental']

# %%
X
# Out:
#      season  year  Month  is_holiday  weekdaynum  is_workingday  \
# 0         1     0      1           0           6              0
# 1         1     0      1           0           0              0
# 2         1     0      1           0           1              1
# 3         1     0      1           0           2              1
# 4         1     0      1           0           3              1
# ..      ...   ...    ...         ...         ...            ...
# 594       3     1      8           0           5              1
# 595       3     1      8           0           6              0
# 596       3     1      8           0           0              0
# 597       3     1      8           0           1              1
# 598       3     1      8           0           2              1
#
#      weathersituation  atemp_normalized  humidity_normalized  \
# 0                   2          0.363625             0.805833
# 1                   2          0.353739             0.696087
# ...

# %%
df1["total_rental"]=0

# %%
test_x=df1.drop(['total_rental'], axis = 1)
test_y = df1['total_rental']

# %%
test_x
# Out:
#      season  year  Month  is_holiday  weekdaynum  is_workingday  \
# 0         3     1      8           0           3              1
# 1         3     1      8           0           4              1
# 2         3     1      8           0           5              1
# 3         3     1      8           0           6              0
# 4         3     1      8           0           0              0
# ..      ...   ...    ...         ...         ...            ...
# 126       1     1     12           0           3              1
# 127       1     1     12           0           4              1
# 128       1     1     12           0           5              1
# 129       1     1     12           0           6              0
# 130       1     1     12           0           0              0
#
#      weathersituation  atemp_normalized  humidity_normalized  \
# 0                   1          0.621854             0.677083
# 1                   1          0.637008             0.635833
# ...

# %%
import xgboost
Classifier=xgboost.XGBRegressor()
Classifier.fit(X,y)

mod_pred=Classifier.predict(test_x)
# Out:
# C:\Users\SNEHA\anaconda3\lib\site-packages\xgboost\data.py:192: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=12, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
mod_pred
# Out:
# array([7547.58  , 7574.5547, 7559.1265, 5402.4204, 4700.423 , 6660.791 ,
#        6878.4736, 7708.319 , 7564.554 , 7104.4556, 7181.7017, 5788.797 ,
#        5608.385 , 5889.5913, 6475.83  , 5965.4   , 6261.582 , 4226.35  ,
#        6979.449 , 6930.0073, 7614.7007, 7464.3335, 7469.1465, 7348.2095,
#        7770.9746, 6743.783 , 6805.871 , 4711.947 , 7390.203 , 7374.018 ,
#        7973.3394, 7209.4336, 6870.946 , 7294.12  , 7110.708 , 7462.9507,
#        7317.063 , 7271.7437, 7415.7886, 6962.536 , 7210.5596, 5276.849 ,
#        5875.597 , 7114.7446, 7500.145 , 6997.3423, 6108.241 , 5114.424 ,
#        5953.4766, 7236.554 , 6823.989 , 7296.3994, 6339.516 , 6615.2437,
#        6654.2905, 7116.207 , 6948.2666, 4581.3384, 6108.3975, 7039.007 ,
#        5699.967 , 6903.0874, 7363.9463, 7379.283 , 6573.628 , 6247.406 ,
#        4581.1675, 5953.74  , 4322.486 , 4060.9836, 5445.2026, 6044.0415,
#        6805.637 , 6072.969 , 5565.3394, 6125.2197, 5731.184 , 5588.524 ,
# ...

# %%
from sklearn.metrics import mean_squared_error

mse1 = mean_squared_error(test_y, mod_pred)

import math

rmse1 = math.sqrt(mse1)

print(rmse1)
# Out:
# 6070.849692774415

# %%
y_pred=mod_pred.round(0).astype(int)

# %%
df2 = pd.DataFrame({
    "ID":z,
    "total_count": y_pred
})

df2.to_csv("submission1.csv", index=False)

# %%
df2
# Out:
#        ID  total_count
# 0    A600         7548
# 1    A601         7575
# 2    A602         7559
# 3    A603         5402
# 4    A604         4700
# ..    ...          ...
# 126  A726         2812
# 127  A727         3380
# 128  A728         4628
# 129  A729         2790
# 130  A730         2731
#
# [131 rows x 2 columns]
